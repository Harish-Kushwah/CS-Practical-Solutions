# %% [markdown]
# Q. 2)Download the Market basket dataset. Write a python program to read the dataset and display its
# information. Preprocess the data (drop null values etc.) Convert the categorical values into numeric
# format. Apply the apriori algorithm on the above dataset to generate the frequent itemsets and association
# rules.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
import numpy as np

data  = pd.read_csv("C:\\Users\\haris\\Desktop\\TYBCS\\CS-Practical-Solutions\\sem6\\Web_&_DA\\datasets\\market.csv")
data.dropna(inplace=True)
data= np.array(data)

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)

new_df = pd.DataFrame(te_data ,columns  = te.columns_ )

freq_patterns = apriori(new_df ,min_support=0.5 ,use_colnames=True)
print(freq_patterns)

rules = association_rules(freq_patterns,metric ="support", min_threshold=0.05)
print(rules)
# Out:
#     support               itemsets
# 0      0.75                 (Beer)
# 1      0.75                (Bread)
# 2      0.50                 (Coke)
# 3      1.00               (Diaper)
# 4      0.75                 (Milk)
# 5      0.50          (Bread, Beer)
# 6      0.75         (Diaper, Beer)
# 7      0.50           (Milk, Beer)
# 8      0.75        (Bread, Diaper)
# 9      0.50          (Bread, Milk)
# 10     0.50         (Coke, Diaper)
# 11     0.50           (Coke, Milk)
# 12     0.75         (Diaper, Milk)
# 13     0.50  (Bread, Diaper, Beer)
# 14     0.50   (Milk, Diaper, Beer)
# 15     0.50  (Bread, Diaper, Milk)
# 16     0.50   (Coke, Diaper, Milk)
#         antecedents      consequents  antecedent support  consequent support  \
# 0           (Bread)           (Beer)                0.75                0.75
# 1            (Beer)          (Bread)                0.75                0.75
# 2          (Diaper)           (Beer)                1.00                0.75
# 3            (Beer)         (Diaper)                0.75                1.00
# 4            (Milk)           (Beer)                0.75                0.75
# 5            (Beer)           (Milk)                0.75                0.75
# 6           (Bread)         (Diaper)                0.75                1.00
# 7          (Diaper)          (Bread)                1.00                0.75
# 8           (Bread)           (Milk)                0.75                0.75
# 9            (Milk)          (Bread)                0.75                0.75
# 10           (Coke)         (Diaper)                0.50                1.00
# 11         (Diaper)           (Coke)                1.00                0.50
# 12           (Coke)           (Milk)                0.50                0.75
# 13           (Milk)           (Coke)                0.75                0.50
# 14         (Diaper)           (Milk)                1.00                0.75
# 15           (Milk)         (Diaper)                0.75                1.00
# 16  (Bread, Diaper)           (Beer)                0.75                0.75
# 17    (Bread, Beer)         (Diaper)                0.50                1.00
# 18   (Diaper, Beer)          (Bread)                0.75                0.75
# 19          (Bread)   (Diaper, Beer)                0.75                0.75
# 20         (Diaper)    (Bread, Beer)                1.00                0.50
# 21           (Beer)  (Bread, Diaper)                0.75                0.75
# 22   (Diaper, Milk)           (Beer)                0.75                0.75
# 23     (Beer, Milk)         (Diaper)                0.50                1.00
# 24   (Diaper, Beer)           (Milk)                0.75                0.75
# 25           (Milk)   (Diaper, Beer)                0.75                0.75
# 26         (Diaper)     (Beer, Milk)                1.00                0.50
# 27           (Beer)   (Diaper, Milk)                0.75                0.75
# 28  (Bread, Diaper)           (Milk)                0.75                0.75
# 29    (Bread, Milk)         (Diaper)                0.50                1.00
# 30   (Diaper, Milk)          (Bread)                0.75                0.75
# 31          (Bread)   (Diaper, Milk)                0.75                0.75
# 32         (Diaper)    (Bread, Milk)                1.00                0.50
# 33           (Milk)  (Bread, Diaper)                0.75                0.75
# 34   (Coke, Diaper)           (Milk)                0.50                0.75
# 35     (Coke, Milk)         (Diaper)                0.50                1.00
# 36   (Diaper, Milk)           (Coke)                0.75                0.50
# 37           (Coke)   (Diaper, Milk)                0.50                0.75
# 38         (Diaper)     (Coke, Milk)                1.00                0.50
# 39           (Milk)   (Coke, Diaper)                0.75                0.50
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0      0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 1      0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 2      0.75    0.750000  1.000000    0.0000        1.00       0.000000
# 3      0.75    1.000000  1.000000    0.0000         inf       0.000000
# 4      0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 5      0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 6      0.75    1.000000  1.000000    0.0000         inf       0.000000
# 7      0.75    0.750000  1.000000    0.0000        1.00       0.000000
# 8      0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 9      0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 10     0.50    1.000000  1.000000    0.0000         inf       0.000000
# 11     0.50    0.500000  1.000000    0.0000        1.00       0.000000
# 12     0.50    1.000000  1.333333    0.1250         inf       0.500000
# 13     0.50    0.666667  1.333333    0.1250        1.50       1.000000
# 14     0.75    0.750000  1.000000    0.0000        1.00       0.000000
# 15     0.75    1.000000  1.000000    0.0000         inf       0.000000
# 16     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 17     0.50    1.000000  1.000000    0.0000         inf       0.000000
# 18     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 19     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 20     0.50    0.500000  1.000000    0.0000        1.00       0.000000
# 21     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 22     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 23     0.50    1.000000  1.000000    0.0000         inf       0.000000
# 24     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 25     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 26     0.50    0.500000  1.000000    0.0000        1.00       0.000000
# 27     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 28     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 29     0.50    1.000000  1.000000    0.0000         inf       0.000000
# 30     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 31     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 32     0.50    0.500000  1.000000    0.0000        1.00       0.000000
# 33     0.50    0.666667  0.888889   -0.0625        0.75      -0.333333
# 34     0.50    1.000000  1.333333    0.1250         inf       0.500000
# 35     0.50    1.000000  1.000000    0.0000         inf       0.000000
# 36     0.50    0.666667  1.333333    0.1250        1.50       1.000000
# 37     0.50    1.000000  1.333333    0.1250         inf       0.500000
# 38     0.50    0.500000  1.000000    0.0000        1.00       0.000000
# 39     0.50    0.666667  1.333333    0.1250        1.50       1.000000
